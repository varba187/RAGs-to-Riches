# %% [markdown]
# <a href="https://colab.research.google.com/github/varba187/RAGs-to-Riches/blob/main/code/notebooks/final_comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
t5 = pd.read_csv("t5_eval_results.csv")
dpr = pd.read_csv("dpr_results.csv")
rag_token = pd.read_csv("rag_token_results.csv")
rag_sequence = pd.read_csv("rag_sequence_results.csv")

# %%
table = pd.DataFrame([
    {
        "Model": "T5-base",
        "Book": "Closed",
        "NQ": t5["f1"].mean() * 100,
        "Metrics": "F1"
    },
    {
        "Model": "DPR",
        "Book": "Open",
        "NQ": dpr["recall_at_10"].mean() * 100,
        "Metrics": "Recall@10"
    },
    {
        "Model": "RAG-Token",
        "Book": "Open",
        "NQ": rag_token["f1"].mean() * 100,
        "Metrics": "F1"
    },
    {
        "Model": "RAG-Sequence",
        "Book": "Open",
        "NQ": rag_sequence["f1"].mean() * 100,
        "Metrics": "F1"
    },
])

# %%
table["NQ"] = paper["NQ"].round(2)
paper.to_csv("final_comparison_table.csv", index = False)

table
